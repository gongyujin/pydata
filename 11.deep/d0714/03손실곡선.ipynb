# %% [markdown]
# <a href="https://colab.research.google.com/github/gongyujin/pydata/blob/master/11.deep/d0714/03%EC%86%90%EC%8B%A4%EA%B3%A1%EC%84%A0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow import keras
import sklearn
from sklearn.linear_model import SGDClassifier
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
# mnist파일 불러오기
# keras mnist파일이 설치될때 자동설치가 됨
# 튜플형태로 자동적으로 가져오게 됨
(train_data,train_label),(test_data,test_label)=keras.datasets.fashion_mnist.load_data()

# %%
train_scaled=train_data/255.0
test_scaled=test_data/255.0

# %%
sub_scaled,val_scaled,sub_label,val_label=train_test_split(train_scaled,train_label)

# %%
# 딥러닝 선언
model=keras.Sequential()
model.add(keras.layers.Flatten(input_shape=(28,28)))
model.add(keras.layers.Dense(100,activation="relu"))
model.add(keras.layers.Dense(10,activation='softmax'))

# %%
# 딥러닝 설정
model.compile(optimizer='adam',loss="sparse_categorical_crossentropy",metrics='accuracy')

# %%
# 훈련
history = model.fit(sub_scaled,sub_label,epochs=20,validation_data=(val_scaled,val_label))
# [loss,accuracy] 출력됨
print(history.history['loss'])
print(history.history['accuracy'])
# Out:
# Epoch 1/20
# 1407/1407 [==============================] - 5s 3ms/step - loss: 0.5316 - accuracy: 0.8135 - val_loss: 0.4411 - val_accuracy: 0.8447
# Epoch 2/20
# 1407/1407 [==============================] - 4s 3ms/step - loss: 0.3983 - accuracy: 0.8564 - val_loss: 0.4308 - val_accuracy: 0.8411
# Epoch 3/20
# 1407/1407 [==============================] - 4s 3ms/step - loss: 0.3581 - accuracy: 0.8702 - val_loss: 0.3515 - val_accuracy: 0.8742
# Epoch 4/20
# 1407/1407 [==============================] - 4s 3ms/step - loss: 0.3319 - accuracy: 0.8791 - val_loss: 0.3600 - val_accuracy: 0.8692
# Epoch 5/20
# 1407/1407 [==============================] - 4s 3ms/step - loss: 0.3120 - accuracy: 0.8854 - val_loss: 0.3567 - val_accuracy: 0.8745
# Epoch 6/20
# 1407/1407 [==============================] - 4s 3ms/step - loss: 0.2970 - accuracy: 0.8895 - val_loss: 0.3560 - val_accuracy: 0.8708
# Epoch 7/20
# 1407/1407 [==============================] - 4s 3ms/step - loss: 0.2842 - accuracy: 0.8951 - val_loss: 0.3261 - val_accuracy: 0.8814
# Epoch 8/20
# 1407/1407 [==============================] - 7s 5ms/step - loss: 0.2723 - accuracy: 0.8990 - val_loss: 0.3124 - val_accuracy: 0.8881
# Epoch 9/20
# 1407/1407 [==============================] - 4s 3ms/step - loss: 0.2619 - accuracy: 0.9027 - val_loss: 0.3358 - val_accuracy: 0.8785
# Epoch 10/20
# 1407/1407 [==============================] - 5s 3ms/step - loss: 0.2530 - accuracy: 0.9057 - val_loss: 0.3244 - val_accuracy: 0.8843
# Epoch 11/20
# 1407/1407 [==============================] - 4s 3ms/step - loss: 0.2447 - accuracy: 0.9084 - val_loss: 0.3292 - val_accuracy: 0.8846
# Epoch 12/20
# 1407/1407 [==============================] - 4s 3ms/step - loss: 0.2372 - accuracy: 0.9110 - val_loss: 0.3244 - val_accuracy: 0.8863
# Epoch 13/20
# 1407/1407 [==============================] - 4s 3ms/step - loss: 0.2282 - accuracy: 0.9156 - val_loss: 0.3341 - val_accuracy: 0.8837
# Epoch 14/20
# 1407/1407 [==============================] - 5s 3ms/step - loss: 0.2239 - accuracy: 0.9168 - val_loss: 0.3308 - val_accuracy: 0.8884
# Epoch 15/20
# 1407/1407 [==============================] - 5s 3ms/step - loss: 0.2161 - accuracy: 0.9193 - val_loss: 0.3168 - val_accuracy: 0.8928
# Epoch 16/20
# 1407/1407 [==============================] - 5s 3ms/step - loss: 0.2096 - accuracy: 0.9226 - val_loss: 0.3353 - val_accuracy: 0.8857
# Epoch 17/20
# 1407/1407 [==============================] - 4s 3ms/step - loss: 0.2055 - accuracy: 0.9233 - val_loss: 0.3358 - val_accuracy: 0.8877
# Epoch 18/20
# 1407/1407 [==============================] - 4s 3ms/step - loss: 0.1987 - accuracy: 0.9252 - val_loss: 0.3357 - val_accuracy: 0.8875
# Epoch 19/20
# 1407/1407 [==============================] - 4s 3ms/step - loss: 0.1951 - accuracy: 0.9263 - val_loss: 0.3360 - val_accuracy: 0.8928
# Epoch 20/20
# 1407/1407 [==============================] - 4s 3ms/step - loss: 0.1894 - accuracy: 0.9288 - val_loss: 0.3395 - val_accuracy: 0.8924
# [0.5315741896629333, 0.39828750491142273, 0.35810428857803345, 0.33194857835769653, 0.3120489716529846, 0.29695335030555725, 0.2842099666595459, 0.2723114490509033, 0.2619423270225525, 0.25297603011131287, 0.24468030035495758, 0.2371528148651123, 0.22820229828357697, 0.2238614857196808, 0.21612918376922607, 0.20963610708713531, 0.20550668239593506, 0.19874410331249237, 0.19506235420703888, 0.18935824930667877]
# [0.8135111331939697, 0.8563555479049683, 0.870199978351593, 0.8791333436965942, 0.885355532169342, 0.8895111083984375, 0.895111083984375, 0.8990222215652466, 0.9026666879653931, 0.9056666493415833, 0.9083555340766907, 0.9109777808189392, 0.9156444668769836, 0.9168000221252441, 0.9193333387374878, 0.9225555658340454, 0.923288881778717, 0.9252222180366516, 0.9263333082199097, 0.9287777543067932]

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(history.history['val_accuracy'])
plt.xlabel('epoch')
plt.ylabel('val_accuracy')
plt.show()

# %%
plt.plot(history.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('val_loss')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['accuracy'])
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.show()
